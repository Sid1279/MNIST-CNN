# %%
import pickle
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt

# %%
###CNN MODEL

# # Encapsulate data in custom class to be used with PyTorch's DataLoader
# class CIFAR2ClassDataset(Dataset):
#     def __init__(self, data, targets):
#         self.data = data
#         self.targets = targets

#     def __len__(self):
#         return len(self.data)

#     def __getitem__(self, idx):
#         image = self.data[idx]
#         label = self.targets[idx]
#         return image, label

# # Loading data
# data = pickle.load(open('cifar_2class_py2.p', 'rb'), encoding='bytes')

# train_data = data[b'train_data']
# train_labels = data[b'train_labels']
# test_data = data[b'test_data']
# test_labels = data[b'test_labels']

# # Reshape into 32x32, 3 -> RGB
# train_data = train_data.reshape(-1, 3, 32, 32)
# test_data = test_data.reshape(-1, 3, 32, 32)

# # Convert numpy array into PyTorch tensors
# train_data = torch.from_numpy(train_data).float()
# train_labels = torch.from_numpy(train_labels[:, 0]).long()
# test_data = torch.from_numpy(test_data).float()
# test_labels = torch.from_numpy(test_labels[:, 0]).long()

# # Define the neural network model
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__() #Invoke parent class initializer
#         self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
#         self.relu = nn.ReLU() #ReLU activation
#         self.pool = nn.MaxPool2d(kernel_size=2) #downsizes into 2x2 while preserving important features
#         self.flatten = nn.Flatten() #flattens the 2D input tensor into a 1D tensor
#         self.fc1 = nn.Linear(16 * 16 * 16, 64) #first layer: 16*16*16 inputs, 64 outputs
#         self.fc2 = nn.Linear(64, 2) #second layer: 64 inputs, 2 outputs

#     def forward(self, x):
#         x = self.conv1(x)
#         x = self.relu(x)
#         x = self.pool(x)
#         x = self.flatten(x)
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         return x

# # Initialize the model & define hyperparameters
# model = NeuralNetwork()
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=0.001)
# batch_size = 30
# num_epochs = 10

# # Create custom dataset that is compatible with PyTorch's DataLoader
# train_dataset = CIFAR2ClassDataset(train_data, train_labels)
# test_dataset = CIFAR2ClassDataset(test_data, test_labels)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# train_accuracies = []
# test_accuracies = []

# for epoch in range(num_epochs):
#     train_loss = 0.0
#     train_total = 0
#     train_correct = 0

#     # Training Loop
#     for images, labels in train_loader:
#         optimizer.zero_grad()

#         outputs = model(images)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         _, predicted = torch.max(outputs, 1)
#         train_total += labels.size(0)
#         train_correct += (predicted == labels).sum().item()
#         train_loss += loss.item() * images.size(0)

#     train_loss /= len(train_dataset)
#     train_accuracy = 100.0 * train_correct / train_total
    
#     train_accuracies.append(train_accuracy)
#     print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')
    
#     # Testing loop
#     test_loss = 0.0
#     test_total = 0
#     test_correct = 0
#     with torch.no_grad():
#         for images, labels in test_loader:
#             outputs = model(images)
#             loss = criterion(outputs, labels)

#             _, predicted = torch.max(outputs, 1)
#             test_total += labels.size(0)
#             test_correct += (predicted == labels).sum().item()
#             test_loss += loss.item() * images.size(0)

#     test_loss /= len(test_dataset)
#     test_accuracy = 100.0 * test_correct / test_total
    
#     test_accuracies.append(test_accuracy)
#     print(f'Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.2f}%')

# %%
# ###MLP MODEL - WITHOUT TENSORBOARD

# # Encapsulate data in custom class to be used with PyTorch's DataLoader
# class CIFAR2ClassDataset(Dataset):
#     def __init__(self, data, targets):
#         self.data = data
#         self.targets = targets

#     def __len__(self):
#         return len(self.data)

#     def __getitem__(self, idx):
#         image = self.data[idx]
#         label = self.targets[idx]
#         return image, label

# # Loading data
# data = pickle.load(open('cifar_2class_py2.p', 'rb'), encoding='bytes')

# train_data = data[b'train_data']
# train_labels = data[b'train_labels']
# test_data = data[b'test_data']
# test_labels = data[b'test_labels']

# # Reshape into 32x32, 3 -> RGB
# train_data = train_data.reshape(-1, 3, 32, 32)
# test_data = test_data.reshape(-1, 3, 32, 32)

# # Convert numpy array into PyTorch tensors
# train_data = torch.from_numpy(train_data).float()
# train_labels = torch.from_numpy(train_labels[:, 0]).long()
# test_data = torch.from_numpy(test_data).float()
# test_labels = torch.from_numpy(test_labels[:, 0]).long()

# # Define the neural network model
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__()  # Invoke parent class initializer
#         self.flatten = nn.Flatten()  # flattens the 2D input tensor into a 1D tensor
#         self.fc1 = nn.Linear(3 * 32 * 32, 64)  # first layer: 3*32*32 inputs, 64 outputs
#         self.relu = nn.ReLU()  # ReLU activation
#         self.fc2 = nn.Linear(64, 2)  # second layer: 64 inputs, 2 outputs

#     def forward(self, x):
#         x = self.flatten(x)
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         return x

# # Initialize the model & define hyperparameters
# model = NeuralNetwork()
# criterion = nn.CrossEntropyLoss()
# # optimizer =  optim.Adam(model.parameters(), lr=0.0001)
# optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=0.5)
# batch_size = 50
# num_epochs = 10

# # Create custom dataset that is compatible with PyTorch's DataLoader
# train_dataset = CIFAR2ClassDataset(train_data, train_labels)
# test_dataset = CIFAR2ClassDataset(test_data, test_labels)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# train_accuracies = []
# test_accuracies = []

# for epoch in range(num_epochs):
#     train_loss = 0.0
#     train_total = 0
#     train_correct = 0

#     # Training Loop
#     for images, labels in train_loader:
#         optimizer.zero_grad()

#         outputs = model(images)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#         _, predicted = torch.max(outputs, 1)
#         train_total += labels.size(0)
#         train_correct += (predicted == labels).sum().item()
#         train_loss += loss.item() * images.size(0)

#     train_loss /= len(train_dataset)
#     train_accuracy = 100.0 * train_correct / train_total
    
#     train_accuracies.append(train_accuracy)
#     print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')
    
#     # Testing loop
#     test_loss = 0.0
#     test_total = 0
#     test_correct = 0
#     with torch.no_grad():
#         for images, labels in test_loader:
#             outputs = model(images)
#             loss = criterion(outputs, labels)

#             _, predicted = torch.max(outputs, 1)
#             test_total += labels.size(0)
#             test_correct += (predicted == labels).sum().item()
#             test_loss += loss.item() * images.size(0)

#     test_loss /= len(test_dataset)
#     test_accuracy = 100.0 * test_correct / test_total
    
#     test_accuracies.append(test_accuracy)
#     print(f'Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.2f}%')

# %%
# #VISUALIZATION
# epochs = np.arange(1, num_epochs+1)
# plt.plot(epochs, train_accuracies, color = "purple", label='Train Accuracy')
# plt.plot(epochs, test_accuracies, color = "green", linestyle='--', label='Test Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.title('Accuracies', fontsize = 20, y = 1.05)
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
# # Testing loop - Final
# test_loss = 0.0
# test_total = 0
# test_correct = 0
# with torch.no_grad():
#     for images, labels in test_loader:
#         outputs = model(images)
#         loss = criterion(outputs, labels)

#         _, predicted = torch.max(outputs, 1)
#         test_total += labels.size(0)
#         test_correct += (predicted == labels).sum().item()
#         test_loss += loss.item() * images.size(0)

# test_loss /= len(test_dataset)
# test_accuracy = 100.0 * test_correct / test_total

# print(f'Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.2f}%')

# %%
### MLP MODEL

# Encapsulate data in a custom class to be used with PyTorch's DataLoader
class CIFAR2ClassDataset(Dataset):
    def __init__(self, data, targets):
        self.data = data
        self.targets = targets

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx]
        label = self.targets[idx]
        return image, label

# Loading data
data = pickle.load(open('cifar_2class_py2.p', 'rb'), encoding='bytes')

train_data = data[b'train_data']
train_labels = data[b'train_labels']
test_data = data[b'test_data']
test_labels = data[b'test_labels']

# Reshape into 32x32, 3 -> RGB
train_data = train_data.reshape(-1, 3, 32, 32)
test_data = test_data.reshape(-1, 3, 32, 32)

# Convert numpy array into PyTorch tensors
train_data = torch.from_numpy(train_data).float()
train_labels = torch.from_numpy(train_labels[:, 0]).long()
test_data = torch.from_numpy(test_data).float()
test_labels = torch.from_numpy(test_labels[:, 0]).long()

# Define the neural network model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()  # Invoke parent class initializer
        self.flatten = nn.Flatten()  # flattens the 2D input tensor into a 1D tensor
        self.fc1 = nn.Linear(3 * 32 * 32, 64)  # first layer: 3*32*32 inputs, 64 outputs
        self.relu = nn.ReLU()  # ReLU activation
        self.fc2 = nn.Linear(64, 2)  # second layer: 64 inputs, 2 outputs

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# Initialize the model & define hyperparameters
model = NeuralNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=0.4)
batch_size = 50
num_epochs = 2

# Create custom dataset that is compatible with PyTorch's DataLoader
train_dataset = CIFAR2ClassDataset(train_data, train_labels)
test_dataset = CIFAR2ClassDataset(test_data, test_labels)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

train_accuracies = []
test_accuracies = []

# Create a SummaryWriter for Tensorboard
writer = SummaryWriter()

for epoch in range(num_epochs):
    train_loss = 0.0
    train_total = 0
    train_correct = 0

    # Training Loop
    for images, labels in train_loader:
        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
        train_loss += loss.item() * images.size(0)

    train_loss /= len(train_dataset)
    train_accuracy = 100.0 * train_correct / train_total

    train_accuracies.append(train_accuracy)
    print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')
    # Write training metrics to Tensorboard
    writer.add_scalar('Loss/Train', train_loss, epoch)
    writer.add_scalar('Accuracy/Train', train_accuracy, epoch)

    # Testing loop
    test_loss = 0.0
    test_total = 0
    test_correct = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
            test_loss += loss.item() * images.size(0)

    test_loss /= len(test_dataset)
    test_accuracy = 100.0 * test_correct / test_total

    test_accuracies.append(test_accuracy)
    print(f'Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.2f}%')

    # Write testing metrics to Tensorboard
    writer.add_scalar('Loss/Test', test_loss, epoch)
    writer.add_scalar('Accuracy/Test', test_accuracy, epoch)

    # Select a few images from the test dataset
    sample_images, _ = next(iter(test_loader))
    # Write the images to Tensorboard
    writer.add_images('Images', sample_images, global_step=epoch)

# Close the SummaryWriter
writer.close()

# Plot the training and testing accuracies over epochs
epochs = range(1, num_epochs + 1)
plt.plot(epochs, train_accuracies, 'b', label='Training Accuracy')
plt.plot(epochs, test_accuracies, 'r', label='Testing Accuracy')
plt.title('Training and Testing Accuracies')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# Print overall training and testing accuracies
print(f'Final Training Accuracy: {train_accuracies[-1]:.2f}%')
print(f'Final Testing Accuracy: {test_accuracies[-1]:.2f}%')
# Out:
# Epoch 1/2, Training Loss: 2.1986, Training Accuracy: 64.40%
# Testing Loss: 0.5935, Testing Accuracy: 68.75%
# Epoch 2/2, Training Loss: 0.5798, Training Accuracy: 69.66%
# Testing Loss: 0.5709, Testing Accuracy: 70.60%
# Final Training Accuracy: 69.66%
# Final Testing Accuracy: 70.60%

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 17116), started 5:20:45 ago. (Use '!kill 17116' to kill it.)
#       <iframe id="tensorboard-frame-861ae4c96d3ea6e5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-861ae4c96d3ea6e5");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Data Visualization - Images

# %%
data = pickle.load(open('cifar_2class_py2.p', 'rb'), encoding='bytes')

train_data = data[b'train_data']
train_labels = data[b'train_labels']
test_data = data[b'test_data']
test_labels = data[b'test_labels']

# %%
train_data
# Out:
# array([[134, 131, 128, ..., 136, 137, 138],
#        [202, 202, 204, ..., 243, 243, 243],
#        [126, 122, 126, ..., 109, 107, 102],
#        ...,
#        [255, 255, 253, ..., 123, 121, 122],
#        [155, 154, 154, ...,  71,  72,  72],
#        [156, 155, 156, ..., 163, 162, 162]], dtype=uint8)

# %%
train_data_reshaped = np.reshape(train_data, (len(train_data), 3, 32, 32)).transpose(0, 2, 3, 1)
test_data_reshaped = np.reshape(test_data, (len(test_data), 3, 32, 32)).transpose(0, 2, 3, 1)

class_names = ["plane", "ship"]

# Function to display multiple images
def plot_images(images, labels, num_images):
    fig, axes = plt.subplots(10, 10, figsize=(12, 12))
    axes = axes.ravel()

    for i in range(num_images):
        axes[i].imshow(images[i])
        axes[i].set_title(class_names[int(labels[i])])
        axes[i].axis('off')

    plt.tight_layout()
    plt.subplots_adjust(bottom=-0.3)
    plt.show()

# Display 100 images from the training set
num_images = 100
plot_images(train_data_reshaped[:num_images], train_labels[:num_images], num_images)

# %%
### MLP MODEL

# Encapsulate data in a custom class to be used with PyTorch's DataLoader
class CIFAR2ClassDataset(Dataset):
    def __init__(self, data, targets):
        self.data = data
        self.targets = targets

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx]
        label = self.targets[idx]
        return image, label

# Loading data
data = pickle.load(open('cifar_2class_py2.p', 'rb'), encoding='bytes')

train_data = data[b'train_data']
train_labels = data[b'train_labels']
test_data = data[b'test_data']
test_labels = data[b'test_labels']


# Reshape into 32x32, 3 -> RGB
train_data = train_data.reshape(-1, 3, 32, 32)
test_data = test_data.reshape(-1, 3, 32, 32)

# Convert numpy array into PyTorch tensors
train_data = torch.from_numpy(train_data).float()
train_labels = torch.from_numpy(train_labels[:, 0]).long()
test_data = torch.from_numpy(test_data).float()
test_labels = torch.from_numpy(test_labels[:, 0]).long()

# Define the neural network model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()  # Invoke parent class initializer
        self.flatten = nn.Flatten()  # flattens the 2D input tensor into a 1D tensor
        self.fc1 = nn.Linear(3 * 32 * 32, 64)  # first layer: 3*32*32 inputs, 64 outputs
        self.relu = nn.ReLU()  # ReLU activation
        self.fc2 = nn.Linear(64, 2)  # second layer: 64 inputs, 2 outputs

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# Initialize the model & define hyperparameters
model = NeuralNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=0.4)
batch_size = 50
num_epochs = 10

# #PRESERVES batch arrangement
# # Assuming train_data is a 4D tensor of shape (n, 3, 32, 32)
# # Flatten the last three dimensions
# flattened = train_data.view(train_data.size(0), -1)
# # Create a random permutation for each sample in the batch
# permutation = torch.randperm(flattened.size(1))
# # Apply the permutation
# shuffled = flattened[:, permutation]
# # Reshape back to original shape
# train_data = shuffled.view(train_data.shape)

# #DOES NOT PRESERVE batch arrangement
# # Assuming train_data is a 4D tensor of shape (n, 3, 32, 32) 
# # Flatten the last three dimensions
# flattened = train_data.reshape(-1) #flattens the tensor into a 1D tensor
# # Create a random permutation
# permutation = torch.randperm(flattened.size(0))
# # Apply the permutation
# shuffled = flattened[permutation]
# # Reshape back to original shape
# train_data = shuffled.view(train_data.shape)

# Create custom dataset that is compatible with PyTorch's DataLoader
train_dataset = CIFAR2ClassDataset(train_data, train_labels)
test_dataset = CIFAR2ClassDataset(test_data, test_labels)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

train_accuracies = []
test_accuracies = []

# Create a SummaryWriter for Tensorboard
writer = SummaryWriter()

for epoch in range(num_epochs):
    train_loss = 0.0
    train_total = 0
    train_correct = 0

    # Training Loop
    for images, labels in train_loader:
        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
        train_loss += loss.item() * images.size(0)

    train_loss /= len(train_dataset)
    train_accuracy = 100.0 * train_correct / train_total

    train_accuracies.append(train_accuracy)
    print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')
    # Write training metrics to Tensorboard
    writer.add_scalar('Loss/Train', train_loss, epoch)
    writer.add_scalar('Accuracy/Train', train_accuracy, epoch)

    # Testing loop
    test_loss = 0.0
    test_total = 0
    test_correct = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
            test_loss += loss.item() * images.size(0)

    test_loss /= len(test_dataset)
    test_accuracy = 100.0 * test_correct / test_total

    test_accuracies.append(test_accuracy)
    print(f'Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.2f}%')

    # Write testing metrics to Tensorboard
    writer.add_scalar('Loss/Test', test_loss, epoch)
    writer.add_scalar('Accuracy/Test', test_accuracy, epoch)

    # Select a few images from the test dataset
    sample_images, _ = next(iter(test_loader))
    # Write the images to Tensorboard
    writer.add_images('Images', sample_images, global_step=epoch)

# Close the SummaryWriter
writer.close()

# Plot the training and testing accuracies over epochs
epochs = range(1, num_epochs + 1)
plt.plot(epochs, train_accuracies, 'b', label='Training Accuracy')
plt.plot(epochs, test_accuracies, 'r', label='Testing Accuracy')
plt.title('Training and Testing Accuracies')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()

# Print overall training and testing accuracies
print(f'Final Training Accuracy: {train_accuracies[-1]:.2f}%')
print(f'Final Testing Accuracy: {test_accuracies[-1]:.2f}%')
# Out:
# Epoch 1/10, Training Loss: 2.4646, Training Accuracy: 66.72%
# Testing Loss: 0.5783, Testing Accuracy: 70.75%
# Epoch 2/10, Training Loss: 0.5793, Training Accuracy: 69.72%
# Testing Loss: 0.5813, Testing Accuracy: 71.10%
# Epoch 3/10, Training Loss: 0.5602, Training Accuracy: 70.74%
# Testing Loss: 0.5466, Testing Accuracy: 72.40%
# Epoch 4/10, Training Loss: 0.5446, Training Accuracy: 71.93%
# Testing Loss: 0.5357, Testing Accuracy: 73.60%
# Epoch 5/10, Training Loss: 0.5331, Training Accuracy: 72.80%
# Testing Loss: 0.5300, Testing Accuracy: 73.05%
# Epoch 6/10, Training Loss: 0.5224, Training Accuracy: 73.29%
# Testing Loss: 0.5120, Testing Accuracy: 74.20%
# Epoch 7/10, Training Loss: 0.5110, Training Accuracy: 74.01%
# Testing Loss: 0.5133, Testing Accuracy: 74.45%
# Epoch 8/10, Training Loss: 0.5037, Training Accuracy: 74.61%
# Testing Loss: 0.5043, Testing Accuracy: 75.55%
# Epoch 9/10, Training Loss: 0.4939, Training Accuracy: 75.51%
# ...

# %%
data = pickle.load(open('cifar_2class_py2.p', 'rb'), encoding='bytes')

train_data = data[b'train_data']
train_labels = data[b'train_labels']
test_data = data[b'test_data']
test_labels = data[b'test_labels']

# %%
train_data.shape
# Out:
# (10000, 3072)

# %%
first_image = np.reshape(train_data[0], (3, 32, 32)).transpose(1, 2, 0)

# Display the image
plt.imshow(first_image)
plt.title('First Image')
plt.axis('off')
plt.show()
first_image.shape
# Out:
# (32, 32, 3)

# %%
# Reshape into 32x32, 3 -> RGB
train_data = train_data.reshape(-1, 3, 32, 32)
test_data = test_data.reshape(-1, 3, 32, 32)

# Convert numpy array into PyTorch tensors
train_data = torch.from_numpy(train_data).float()
train_labels = torch.from_numpy(train_labels[:, 0]).long()
test_data = torch.from_numpy(test_data).float()
test_labels = torch.from_numpy(test_labels[:, 0]).long()

# %%
# Assuming train_data is a 4D tensor of shape (n, 3, 32, 32) 
# Flatten the last three dimensions
flattened = train_data.reshape(-1) #flattens the tensor into a 1D tensor
# Create a random permutation
permutation = torch.randperm(flattened.size(0))
# Apply the permutation
shuffled = flattened[permutation]
# Reshape back to original shape
train_data_shuffled = shuffled.view(train_data.shape)

# %%
train_data_reshaped = train_data_shuffled.reshape(train_data_shuffled.size(0), -1)
train_data_reshaped = train_data_reshaped.numpy()

first_image = np.reshape(train_data_reshaped[0], (3, 32, 32)).transpose(1, 2, 0)/255.0

# Display the image
plt.imshow(first_image)
plt.title('First Image')
plt.axis('off')
plt.show()

first_image.shape
# Out:
# (32, 32, 3)
